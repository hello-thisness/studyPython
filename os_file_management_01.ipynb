# %%
#
#   this file. description 
#   os file directory 관리 
#   2025.02.12 
#


import os 
import pandas as pd 


#1 현재 디렉토리 경로 

current_dir = os.getcwd()
print ("현재 디렉토리 :" + current_dir)

#2 현재 디렉토리의 파일 리스트 출력 

print ("현재 디렉토리의 파일 목록 :" )
print (os.listdir(os.getcwd()) )

#3 작업 디렉토리 변경 
# os.chdir ('welcome')


current_dir2 = os.getcwd()
print ("현재 디렉토리 :" + current_dir2)


#4 현재 디렉토리 파일 중 csv 파일을 읽어서 내용을 로드 


for f in os.listdir (current_dir):
    if 'csv' in f:
        print (f)
        data = pd.read_csv ( f, encoding='euc-kr' )

data.head()

# data = pd.read_csv ('welcome/births.csv' )
# Out:
# 현재 디렉토리 :/private/var/mobile/Library/Mobile Documents/iCloud~AsheKube~Carnets/Documents/welcome
# 현재 디렉토리의 파일 목록 :
# ['unlockFolder.png', 'bottom_iphone2.png', 'bottom.png', 'top.png', 'births.csv', 'browse.png', 'Welcome to Carnets.ipynb', 'bottom_iphone.png']
# 현재 디렉토리 :/private/var/mobile/Library/Mobile Documents/iCloud~AsheKube~Carnets/Documents/welcome
# births.csv
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548
